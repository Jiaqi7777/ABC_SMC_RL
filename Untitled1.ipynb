# %%
run standard_MCMC.py -T 1000 --MCMC
# Out:
# /scratch/Rabbit/work/ABC_SMC_RL/standard_MCMC.py:84: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   posterior_samples = torch.tensor(model.get_parameter())
# /scratch/Rabbit/work/ABC_SMC_RL/standard_MCMC.py:112: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mcmc_run = mcmc(torch.tensor(obs._buffers['rewards']), torch.tensor(posterior_samples[-1].reshape(-1)), num_samples=training_steps,  warmup_steps=warmup_steps)
# time: 631530
# goal:  (2, 3)
# start:  (0, 0)
# World Scale:  3x4
# Environment: <GridWorld.GridWorld object at 0x7f9ba866a250>
# State space size: (3, 4)
# Action space size: 4
# Q table size: torch.Size([3, 4, 4])
# Q [[[ -4.52  -3.71  -3.71  -4.52]
# ...
