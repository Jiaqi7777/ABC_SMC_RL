# %%
run standard_MCMC.py -T 1000 --MCMC -g
# Out:
# abc epsilon 0.05
# abc epsilon 0.05
# pCN stepsize 0.01
# /scratch/Rabbit/work/ABC_SMC_RL/standard_MCMC.py:87: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   posterior_samples = torch.tensor(model.get_parameter())
# Namespace(Greedy=True, MCMC=False, epsilon=0.05, save=True, seed=555, show=True, time='252079', training_step=1000)
# time: 252079
# goal:  (2, 3)
# start:  (0, 0)
# World Scale:  3x4
# Environment: <GridWorld.GridWorld object at 0x7f1a60e5baf0>
# State space size: (3, 4)
# Action space size: 4
# Q table size: torch.Size([3, 4, 4])
# Q [[[ -4.52  -3.71  -3.71  -4.52]
#   [ -3.71  -2.85  -2.85  -4.52]
#   [ -2.85  -1.95 -20.95  -3.71]
#   [ -1.95  -1.95  -1.    -2.85]]
#
#  [[ -4.52  -2.85  -2.85  -3.71]
#   [ -3.71 -20.95  -1.95  -3.71]
#   [ -2.85  -1.    -1.    -2.85]
#   [ -1.95  -1.     0.   -20.95]]
#
# ...

# %%
h
# Out:
# 239

# %%
R
# Out:
# -240
